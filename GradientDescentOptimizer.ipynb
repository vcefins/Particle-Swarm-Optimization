# %%
from utils import *
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display
import time
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
from optimizer import Optimizer
from function_classes import SimpleConvex, Rastrigin, Rosenbrock

opt = Optimizer()
opt.initialize_particles()
function = Rastrigin()
opt.set_benchmark_function(function)
# Out:
# INFO:root:Particles initialized at: [[1.0259999999996667, -0.8430000000001274], [-1.2510000000000825, -1.283000000000079], [1.6429999999995988, 0.7839999999996934], [1.2999999999996366, 1.5839999999996053], [0.9919999999996705, -0.7230000000001406], [1.9639999999995634, -1.300000000000077], [1.2799999999996388, -0.3310000000001838], [0.01199999999977841, -1.238000000000084], [-1.8050000000000215, 1.7559999999995863], [-0.6670000000001468, -0.4680000000001687], [1.0649999999996624, 1.7379999999995883], [1.7169999999995906, 0.2909999999997477], [-0.17000000000020155, 1.8289999999995783], [-0.28700000000018866, 1.7989999999995816], [-0.1150000000002076, -1.27300000000008], [0.059999999999773124, 0.6109999999997124], [0.668999999999706, -0.2350000000001944], [1.7539999999995866, -0.8960000000001216], [1.1199999999996564, -1.5120000000000537], [1.5889999999996047, 1.6319999999996]]

# %%
# fig = plt.figure()
X, Y, Z = F('rastrigin')
p = plt.pcolor(X, Y, Z)
fig.colorbar(p)
x_min = np.min(Z, axis=0)
y_min = np.min(Z, axis=1)
plt.scatter(0, 0, color='white')
plt.xlim(-2, 2)
plt.ylim(-2, 2)

for idx in opt.gradient_descent(lr=0.001):

    for particle in opt.particle_coordinates:
        plt.scatter(*particle)
    display.clear_output(wait=True)
    display.display(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-46220868fb57> in <module>
#      14         plt.scatter(*particle)
#      15     display.clear_output(wait=True)
# ---> 16     display.display(plt.gcf())
#
# /mnt/d/MSAI/ARS/Assignments/arsenv/lib/python3.5/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /mnt/d/MSAI/ARS/Assignments/arsenv/lib/python3.5/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
# ...
